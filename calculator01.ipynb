# %% [markdown]
# <a href="https://colab.research.google.com/github/safdarmarwat/colab/blob/main/calculator01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple Calculator in Python

def calculator():
    print("Simple Calculator")
    print("Operations: +  -  *  /")

    num1 = float(input("Enter first number: "))
    op = input("Enter operator (+, -, *, /): ")
    num2 = float(input("Enter second number: "))

    if op == '+':
        print("Result:", num1 + num2)
    elif op == '-':
        print("Result:", num1 - num2)
    elif op == '*':
        print("Result:", num1 * num2)
    elif op == '/':
        if num2 != 0:
            print("Result:", num1 / num2)
        else:
            print("Error: Division by zero!")
    else:
        print("Invalid operator!")

calculator()
# Out:
# Simple Calculator
# Operations: +  -  *  /
# Enter first number: 1
# Enter operator (+, -, *, /): -
# Enter second number: 4
# Result: -3.0

# %%
import math

while True:
    print("\n--- Advanced Calculator ---")
    print("Operations:")
    print("+  -  *  /  (basic)")
    print("sqrt (square root)")
    print("^ (power)")
    print("log (log base 10)")

    op = input("Enter operation: ")

    # Square root
    if op == "sqrt":
        num = float(input("Enter number: "))
        if num >= 0:
            print("Result:", math.sqrt(num))
        else:
            print("Error: Negative number!")

    # Power
    elif op == "^":
        base = float(input("Enter base: "))
        exp = float(input("Enter exponent: "))
        print("Result:", math.pow(base, exp))

    # Logarithm base 10
    elif op == "log":
        num = float(input("Enter number: "))
        if num > 0:
            print("Result:", math.log10(num))
        else:
            print("Error: Log undefined!")

    # Basic operations
    else:
        num1 = float(input("Enter first number: "))
        num2 = float(input("Enter second number: "))

        if op == '+':
            print("Result:", num1 + num2)
        elif op == '-':
            print("Result:", num1 - num2)
        elif op == '*':
            print("Result:", num1 * num2)
        elif op == '/':
            if num2 != 0:
                print("Result:", num1 / num2)
            else:
                print("Error: Division by zero!")
        else:
            print("Invalid operation!")

    choice = input("Continue? (y/n): ")
    if choice.lower() != 'y':
        print("Calculator stopped.")
        break
# Out:
# --- Advanced Calculator ---
# Operations:
# +  -  *  /  (basic)
# sqrt (square root)
# ^ (power)
# log (log base 10)
# Enter operation: ^
# Enter base: 6
# Enter exponent: 3
# Result: 216.0
# Continue? (y/n): n
# Calculator stopped.
